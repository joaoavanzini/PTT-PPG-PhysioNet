# %% [markdown]
# # Starting the Data Analysis

# %% [markdown]
# Importing

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Load the 'subjects_info.csv' file into a DataFrame

# %%
subjects_info_df = pd.read_csv('/Users/palhares/Documents/msc/PTT-PPG-PhysioNet/physionet.org/files/pulse-transit-time-ppg/1.1.0/csv/subjects_info.csv')
subjects_info_df
# Out:
#       record activity  gender  height  weight  age  bp_sys_start  bp_sys_end
# 0    s1_walk     walk  female     160      50   25            94          90  \
# 1     s1_run      run  female     160      50   25            92          94
# 2     s1_sit      sit  female     160      50   25            87          87
# 3    s2_walk     walk    male     175      70   20           125         122
# 4     s2_run      run    male     175      70   20           122         136
# ..       ...      ...     ...     ...     ...  ...           ...         ...
# 61   s21_sit      sit  female     170      60   25           129         113
# 62   s21_run      run  female     170      60   25           113         125
# 63  s22_walk     walk  female     155      45   20           104         101
# 64   s22_run      run  female     155      45   20           101         108
# 65   s22_sit      sit  female     155      45   20           108         102
#
# ...

# %% [markdown]
# Display basic information about the DataFrame

# %%
print("Basic Info:")
print(subjects_info_df.info())
# Out:
# Basic Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   record        66 non-null     object
#  1   activity      66 non-null     object
#  2   gender        66 non-null     object
#  3   height        66 non-null     int64
#  4   weight        66 non-null     int64
#  5   age           66 non-null     int64
#  6   bp_sys_start  66 non-null     int64
#  7   bp_sys_end    66 non-null     int64
#  8   bp_dia_start  66 non-null     int64
#  9   bp_dia_end    66 non-null     int64
#  10  hr_1_start    66 non-null     int64
#  11  hr_1_end      66 non-null     int64
#  12  hr_2_start    66 non-null     int64
#  13  hr_2_end      66 non-null     int64
#  14  spo2_start    66 non-null     int64
#  15  spo2_end      66 non-null     int64
# dtypes: int64(13), object(3)
# memory usage: 8.4+ KB
# None

# %% [markdown]
# Display summary statistics of numeric columns

# %%
print("Summary Statistics:")
print(subjects_info_df.describe())
# Out:
# Summary Statistics:
#            height      weight        age  bp_sys_start  bp_sys_end
# count   66.000000   66.000000  66.000000     66.000000   66.000000  \
# mean   172.954545   72.045455  28.409091    117.439394  117.121212
# std      8.273092   14.622882   9.036639     14.001240   13.673686
# min    155.000000   45.000000  20.000000     87.000000   87.000000
# 25%    170.000000   60.000000  25.000000    108.000000  110.000000
# 50%    175.000000   70.000000  25.000000    116.000000  116.500000
# 75%    175.000000   80.000000  30.000000    125.000000  124.750000
# max    190.000000  100.000000  55.000000    162.000000  162.000000
#
#        bp_dia_start  bp_dia_end  hr_1_start    hr_1_end  hr_2_start
# count     66.000000   66.000000   66.000000   66.000000   66.000000  \
# mean      75.500000   75.560606   74.727273   75.090909   74.590909
# std        8.968749    8.554133   12.772019   11.720760   12.079197
# ...

# %% [markdown]
# Visualize the distribution of age

# %%
plt.figure(figsize=(8, 6))
sns.histplot(subjects_info_df['age'], bins=20, kde=True)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Visualize the distribution of gender

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=subjects_info_df, x='gender')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Visualize the relationship between height and weight

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=subjects_info_df, x='height', y='weight', hue='gender')
plt.title('Relationship Between Height and Weight')
plt.xlabel('Height (cm)')
plt.ylabel('Weight (kg)')
plt.legend(title='Gender')

# %% [markdown]
# Visualize the distribution of height

# %%
plt.figure(figsize=(8, 6))
sns.histplot(subjects_info_df['height'], bins=20, kde=True)
plt.title('Distribution of Height')
plt.xlabel('Height (cm)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Visualize the relationship between height and age

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=subjects_info_df, x='height', y='age', hue='gender')
plt.title('Relationship Between Height and Age')
plt.xlabel('Height (cm)')
plt.ylabel('Age')
plt.legend(title='Gender')
plt.show()

# %% [markdown]
# Create a box plot to visualize the distribution of height by activity

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=subjects_info_df, x="activity", y="height", palette="viridis")
plt.title('Distribution of Height by Activity')
plt.xlabel('Activity')
plt.ylabel('Height (cm)')
plt.show()

# %% [markdown]
# Visualize the distribution of weight

# %%
plt.figure(figsize=(8, 6))
sns.histplot(subjects_info_df['weight'], bins=20, kde=True)
plt.title('Distribution of Weight')
plt.xlabel('Weight (kg)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Visualize the relationship between weight and age

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=subjects_info_df, x='weight', y='age', hue='gender')
plt.title('Relationship Between Weight and Age')
plt.xlabel('Weight (kg)')
plt.ylabel('Age')
plt.legend(title='Gender')
plt.show()

# %% [markdown]
# Visualize the relationship between activity and age

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=subjects_info_df, x='activity', y='age')
plt.title('Relationship Between Activity and Age')
plt.xlabel('Activity')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# Visualize the relationship between activity and gender

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=subjects_info_df, x='activity', hue='gender')
plt.title('Relationship Between Activity and Gender')
plt.xlabel('Activity')
plt.ylabel('Count')
plt.legend(title='Gender')
plt.show()

# %% [markdown]
# Visualize the distribution of systolic blood pressure at the start of the measurement

# %%
plt.figure(figsize=(8, 6))
sns.histplot(subjects_info_df['bp_sys_start'], bins=20, kde=True)
plt.title('Distribution of Systolic Blood Pressure (Start)')
plt.xlabel('Systolic Blood Pressure (mmHg)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Visualize the distribution of diastolic blood pressure at the start of the measurement

# %%
plt.figure(figsize=(8, 6))
sns.histplot(subjects_info_df['bp_dia_start'], bins=20, kde=True)
plt.title('Distribution of Diastolic Blood Pressure (Start)')
plt.xlabel('Diastolic Blood Pressure (mmHg)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Visualize the distribution of heart rate at the start (OMRON HEM-7322)

# %%
plt.figure(figsize=(8, 6))
sns.histplot(subjects_info_df['hr_1_start'], bins=20, kde=True)
plt.title('Distribution of Heart Rate (Start - OMRON HEM-7322)')
plt.xlabel('Heart Rate (bpm)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Visualize the distribution of heart rate at the end (OMRON HEM-7322)

# %%
plt.figure(figsize=(8, 6))
sns.histplot(subjects_info_df['hr_1_end'], bins=20, kde=True)
plt.title('Distribution of Heart Rate (End - OMRON HEM-7322)')
plt.xlabel('Heart Rate (bpm)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Visualize the distribution of heart rate at the start (iHealth Air)

# %%
plt.figure(figsize=(8, 6))
sns.histplot(subjects_info_df['hr_2_start'], bins=20, kde=True)
plt.title('Distribution of Heart Rate (Start - iHealth Air)')
plt.xlabel('Heart Rate (bpm)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Visualize the distribution of heart rate at the end (iHealth Air)

# %%
plt.figure(figsize=(8, 6))
sns.histplot(subjects_info_df['hr_2_end'], bins=20, kde=True)
plt.title('Distribution of Heart Rate (End - iHealth Air)')
plt.xlabel('Heart Rate (bpm)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Visualize the relationship between age and systolic blood pressure at the start

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=subjects_info_df, x='age', y='bp_sys_start', hue='gender')
plt.title('Relationship Between Age and Systolic BP (Start)')
plt.xlabel('Age (years)')
plt.ylabel('Systolic Blood Pressure (mmHg)')
plt.legend(title='Gender')
plt.show()

# %% [markdown]
# Visualize the relationship between age and systolic blood pressure at the end

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=subjects_info_df, x='age', y='bp_sys_end', hue='gender')
plt.title('Relationship Between Age and Systolic BP (End)')
plt.xlabel('Age (years)')
plt.ylabel('Systolic Blood Pressure (mmHg)')
plt.legend(title='Gender')
plt.show()

# %% [markdown]
# Visualize the distribution of systolic blood pressure at the end of the measurement

# %%
plt.figure(figsize=(8, 6))
sns.histplot(subjects_info_df['bp_sys_end'], bins=20, kde=True)
plt.title('Distribution of Systolic Blood Pressure (End)')
plt.xlabel('Systolic Blood Pressure (mmHg)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Visualize the distribution of diastolic blood pressure at the end of the measurement

# %%
plt.figure(figsize=(8, 6))
sns.histplot(subjects_info_df['bp_dia_end'], bins=20, kde=True)
plt.title('Distribution of Diastolic Blood Pressure (End)')
plt.xlabel('Diastolic Blood Pressure (mmHg)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Visualize the relationship between height and systolic blood pressure at the start

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=subjects_info_df, x='height', y='bp_sys_start', hue='gender')
plt.title('Relationship Between Height and Systolic Blood Pressure (Start)')
plt.xlabel('Height (cm)')
plt.ylabel('Systolic Blood Pressure (mmHg)')
plt.legend(title='Gender')
plt.show()

# %% [markdown]
# Visualize the relationship between height and systolic blood pressure at the end

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=subjects_info_df, x='height', y='bp_sys_end', hue='gender')
plt.title('Relationship Between Height and Systolic BP (End)')
plt.xlabel('Height (cm)')
plt.ylabel('Systolic Blood Pressure (mmHg)')
plt.legend(title='Gender')
plt.show()

# %% [markdown]
# Visualize the relationship between weight and diastolic blood pressure at the start

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=subjects_info_df, x='weight', y='bp_dia_start', hue='gender')
plt.title('Relationship Between Weight and Diastolic BP (Start)')
plt.xlabel('Weight (kg)')
plt.ylabel('Diastolic Blood Pressure (mmHg)')
plt.legend(title='Gender')
plt.show()

# %% [markdown]
# Visualize the relationship between weight and diastolic blood pressure at the end

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=subjects_info_df, x='weight', y='bp_dia_end', hue='gender')
plt.title('Relationship Between Weight and Diastolic BP (End)')
plt.xlabel('Weight (kg)')
plt.ylabel('Diastolic Blood Pressure (mmHg)')
plt.legend(title='Gender')
plt.show()

# %% [markdown]
# Create a pair plot to visualize pairwise relationships between numerical variables

# %%
sns.set(style="ticks")
sns.pairplot(subjects_info_df, hue="gender")
plt.suptitle('Pairwise Relationships Between Numerical Variables', y=1.02)
plt.show()

# %% [markdown]
# Create a violin plot to show the distribution of ages by gender

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(data=subjects_info_df, x="gender", y="age", palette="Set2")
plt.title('Distribution of Ages by Gender')
plt.xlabel('Gender')
plt.ylabel('Age (years)')
plt.show()

# %% [markdown]
# Select only the numeric columns for correlation analysis

# %%
numeric_columns = subjects_info_df.select_dtypes(include='number')

# %% [markdown]
# Compute the correlation matrix for numeric columns

# %%
corr_matrix = numeric_columns.corr()

# %% [markdown]
# Create a heatmap to visualize the correlation matrix

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title('Correlation Matrix of Numerical Variables')
plt.show()

# %% [markdown]
# Reading the dataset - s2_sit.csv

# %%
filename = '/Users/palhares/Documents/msc/PTT-PPG-PhysioNet/physionet.org/files/pulse-transit-time-ppg/1.1.0/csv/s2_sit.csv'
df = pd.read_csv(filename)
df
# Out:
#                               time    ecg  peaks  pleth_1  pleth_2  pleth_3
# 0       2021-01-01 15:14:41.324938  31256      0    75338    75758     4866  \
# 1       2021-01-01 15:14:41.326938  31204      0    75338    75758     4866
# 2       2021-01-01 15:14:41.328938  31199      0    75343    75769     4872
# 3       2021-01-01 15:14:41.330938  31243      0    75348    75763     4871
# 4       2021-01-01 15:14:41.332938  31245      0    75352    75766     4883
# ...                            ...    ...    ...      ...      ...      ...
# 246201  2021-01-01 15:22:53.726941  29059      0    74529    74869     4466
# 246202  2021-01-01 15:22:53.728941  31036      0    74529    74869     4466
# 246203  2021-01-01 15:22:53.730941  34134      0    74535    74862     4467
# 246204  2021-01-01 15:22:53.732941  38385      0    74529    74874     4467
# 246205  2021-01-01 15:22:53.734941  43401      0    74523    74882     4462
#
# ...

# %%
df.describe()
# Out:
#                  ecg          peaks        pleth_1       pleth_2
# count  246206.000000  246206.000000  246206.000000  246206.00000  \
# mean    32713.191051       0.004025   74688.971187   75173.41856
# std      5318.388363       0.063316     273.360326     367.46633
# min     12189.000000       0.000000   73944.000000   74093.00000
# 25%     30189.000000       0.000000   74483.000000   74903.00000
# 50%     31700.000000       0.000000   74660.000000   75160.00000
# 75%     34653.000000       0.000000   74898.000000   75455.00000
# max     63763.000000       1.000000   75434.000000   76135.00000
#
#              pleth_3        pleth_4        pleth_5        pleth_6
# count  246206.000000  246206.000000  246206.000000  246206.000000  \
# mean     4684.217655   82790.807754   92392.649087    4173.459778
# std       195.228277     187.577888     426.194660      93.899692
# min      4097.000000   82155.000000   90745.000000    3923.000000
# ...

# %%
df.shape
# Out:
# (246206, 20)

# %% [markdown]
# Check if the 'time' column is present

# %%
if 'time' not in df.columns:
    raise ValueError("The 'time' column does not exist in the CSV file.")

# %% [markdown]
# Transform time to seconds

# %%
df['time'] = pd.to_datetime(df['time'])
df['time'] = df['time'] - df['time'][0]
df['time'] = df['time'].dt.total_seconds()

# %% [markdown]
# Fill non-numeric values with the mean

# %%
df = df.apply(pd.to_numeric, errors='coerce')
df.fillna(df.mean(), inplace=True)

# %% [markdown]
# Calculate the duration of the time series

# %%
start_time = df['time'].iloc[0]
end_time = df['time'].iloc[-1]
duration_seconds = end_time - start_time

# %% [markdown]
# Convert the duration to a human-readable format (e.g., minutes and seconds)

# %%
duration_minutes = int(duration_seconds // 60)
remaining_seconds = int(duration_seconds % 60)
print(f"Duration of the time series: {duration_minutes} minutes and {remaining_seconds} seconds")
# Out:
# Duration of the time series: 8 minutes and 12 seconds

# %% [markdown]
# Plot the time series data - Pleth_1

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['time'], df['pleth_1'], label='PPG Channel 1')
plt.xlabel('Time (seconds)')
plt.ylabel('Amplitude')
plt.title('PPG Signal (Channel 1) over Time')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# List of all signal columns to plot

# %%
signal_columns = ['pleth_1', 'pleth_2', 'pleth_3', 'pleth_4', 'pleth_5', 'pleth_6',
                  'lc_1', 'lc_2', 'temp_1', 'temp_2', 'temp_3']

# %% [markdown]
# Create subplots for all signals

# %%
plt.figure(figsize=(15, 20))
for i, column in enumerate(signal_columns, 1):
    plt.subplot(len(signal_columns), 1, i)
    plt.plot(df['time'], df[column])
    plt.xlabel('Time (seconds)')
    plt.ylabel('Amplitude')
    plt.title(f'Signal: {column}')
    plt.grid(True)

plt.tight_layout()
plt.show()
